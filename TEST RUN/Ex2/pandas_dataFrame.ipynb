# %%
import numpy as np
import pandas as pd
import random as rand
from matplotlib import pyplot as plt
import EX4

# %%
dataset = [rand.random() for i in range(10)]
keys = ['a767',
        'b76769',
        'c241',
        'd0ui',
        'e67396',
        'f6725',
        'g09802',
        'h0928090',
        'i1822',
        'j2829']

# %%
pd.Series(dataset, keys)
# Out:
# a767        0.794864
# b76769      0.457420
# c241        0.600155
# d0ui        0.066354
# e67396      0.837369
# f6725       0.344823
# g09802      0.603535
# h0928090    0.741640
# i1822       0.281197
# j2829       0.377837
# dtype: float64

# %%
def read_from_file(path):
    with open(path, 'r') as file:
        data = [file.readline()[:-2] for i in range(250)]

    header = data[0][3:]
    data.pop(0)
    data = [row.split(',') for row in data]

    for i in range(len(data)):
        data[i][0] = float(data[i][0])
        data[i][1] = float(data[i][1])
        data[i][2] = int(data[i][2])
        data[i][6] = int(data[i][6])
        data[i][7] = int(data[i][7])
        data[i][8] = float(data[i][7])

    return data, header.split(',')

# %%
dataset1, columns = read_from_file('D:\\data visualition\\sample datasets\\Rain_gardens.csv')

# %%
columns
# Out:
# ['X',
#  'Y',
#  'FID',
#  'asset_id',
#  'Material',
#  'Catchment',
#  'No_Inlet',
#  'No_Outlet',
#  'Pit_Depth_m']

# %%
dataset1[:5]
# Out:
# [[151.200169017,
#   -33.886126046,
#   1,
#   'RG286',
#   'Small Pebbles',
#   'Blackwattle Bay',
#   1,
#   1,
#   1.0],
#  [151.221045946,
#   -33.8808990219999,
#   2,
#   'RG001',
#   'Small Pebbles',
#   'Rushcutters Bay',
#   2,
#   1,
#   1.0],
#  [151.226207187,
#   -33.886946511,
#   3,
#   'RG008',
#   'Not Applicable',
#   'Centennial Park',
#   1,
#   1,
#   1.0],
#  [151.226322048,
#   -33.886976209,
#   4,
#   'RG009',
#   'Not Applicable',
#   'Centennial Park',
#   1,
#   1,
#   1.0],
#  [151.210473767,
#   -33.8889328939999,
#   5,
#   'RG011',
#   'Bark Mulch',
#   'Sheas Creek',
#   2,
#   1,
#   1.0]]

# %%
dataset2_0 = pd.DataFrame(dataset1, columns=columns, index=[row[3] for row in dataset1])

# %%
dataset2 = pd.DataFrame(dataset1, columns=columns)

# %%
dataset2.head(6)
# Out:
#             X          Y  FID asset_id        Material        Catchment  \
# 0  151.200169 -33.886126    1    RG286   Small Pebbles  Blackwattle Bay
# 1  151.221046 -33.880899    2    RG001   Small Pebbles  Rushcutters Bay
# 2  151.226207 -33.886947    3    RG008  Not Applicable  Centennial Park
# 3  151.226322 -33.886976    4    RG009  Not Applicable  Centennial Park
# 4  151.210474 -33.888933    5    RG011      Bark Mulch      Sheas Creek
# 5  151.210380 -33.889005    6    RG012  Not Applicable      Sheas Creek
#
#    No_Inlet  No_Outlet  Pit_Depth_m
# 0         1          1          1.0
# 1         2          1          1.0
# 2         1          1          1.0
# 3         1          1          1.0
# 4         2          1          1.0
# 5         2          1          1.0

# %%
dataset2.tail(10)
# Out:
#               X          Y  FID asset_id        Material    Catchment  \
# 239  151.204706 -33.907153  240    RG267   Small Pebbles  Sheas Creek
# 240  151.204427 -33.913831  241    RG268          Gravel    Roseberry
# 241  151.204390 -33.913918  242    RG269          Gravel    Roseberry
# 242  151.203820 -33.905346  243    RG274  Not Applicable  Sheas Creek
# 243  151.203558 -33.905381  244    RG284   Small Pebbles  Sheas Creek
# 244  151.204822 -33.906581  245    RG270   Small Pebbles  Sheas Creek
# 245  151.204265 -33.905925  246    RG272   Small Pebbles  Sheas Creek
# 246  151.204233 -33.905874  247    RG273   Small Pebbles  Sheas Creek
# 247  151.204094 -33.905924  248    RG275   Small Pebbles  Sheas Creek
# 248  151.204135 -33.905966  249    RG276   Small Pebbles  Sheas Creek
#
#      No_Inlet  No_Outlet  Pit_Depth_m
# 239         1          1          1.0
# 240         2          1          1.0
# 241         2          1          1.0
# 242         1          1          1.0
# ...

# %%
dataset2.loc[239]
# Out:
# X                    151.205
# Y                   -33.9072
# FID                      240
# asset_id               RG267
# Material       Small Pebbles
# Catchment        Sheas Creek
# No_Inlet                   1
# No_Outlet                  1
# Pit_Depth_m                1
# Name: 239, dtype: object

# %%
dataset2.iloc[239]
# Out:
# X                    151.205
# Y                   -33.9072
# FID                      240
# asset_id               RG267
# Material       Small Pebbles
# Catchment        Sheas Creek
# No_Inlet                   1
# No_Outlet                  1
# Pit_Depth_m                1
# Name: 239, dtype: object

# %%
dataset2[239]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 239
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-dff14f48c8c1> in <module>
# ...

# %%
dataset2_0.loc['RG284']
# Out:
# X                    151.204
# Y                   -33.9054
# FID                      244
# asset_id               RG284
# Material       Small Pebbles
# Catchment        Sheas Creek
# No_Inlet                   1
# No_Outlet                  1
# Pit_Depth_m                1
# Name: RG284, dtype: object

# %%
dataset2_0.iloc['RG284']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-fab8690045fd> in <module>
# ----> 1 dataset2_0.iloc['RG284']
#       2
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1491             key = item_from_zerodim(key)
#    1492             if not is_integer(key):
# -> 1493                 raise TypeError("Cannot index by location index with a non-integer key")
#    1494
#    1495             # validate the location
#
# ...

# %%
dataset2.loc[1,2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-3962af3633c2> in <module>
# ...

# %%
dataset2.loc[1:,2:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a46db33a80f5> in <module>
# ----> 1 dataset2.loc[1:,2:]
#       2
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ...

# %%
dataset2[1:, 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-a094d9443c50> in <module>
# ----> 1 dataset2[1:, 2]
#       2
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2893             casted_key = self._maybe_cast_indexer(key)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# ...

# %%
dataset2.iloc[1,1]
# Out:
# -33.8808990219999

# %%
dataset2.iloc[[1,1]]
# Out:
#             X          Y  FID asset_id       Material        Catchment  \
# 1  151.221046 -33.880899    2    RG001  Small Pebbles  Rushcutters Bay
# 1  151.221046 -33.880899    2    RG001  Small Pebbles  Rushcutters Bay
#
#    No_Inlet  No_Outlet  Pit_Depth_m
# 1         2          1          1.0
# 1         2          1          1.0

# %%
dataset2[1:]
# Out:
#               X          Y  FID asset_id        Material        Catchment  \
# 1    151.221046 -33.880899    2    RG001   Small Pebbles  Rushcutters Bay
# 2    151.226207 -33.886947    3    RG008  Not Applicable  Centennial Park
# 3    151.226322 -33.886976    4    RG009  Not Applicable  Centennial Park
# 4    151.210474 -33.888933    5    RG011      Bark Mulch      Sheas Creek
# 5    151.210380 -33.889005    6    RG012  Not Applicable      Sheas Creek
# ..          ...        ...  ...      ...             ...              ...
# 244  151.204822 -33.906581  245    RG270   Small Pebbles      Sheas Creek
# 245  151.204265 -33.905925  246    RG272   Small Pebbles      Sheas Creek
# 246  151.204233 -33.905874  247    RG273   Small Pebbles      Sheas Creek
# 247  151.204094 -33.905924  248    RG275   Small Pebbles      Sheas Creek
# 248  151.204135 -33.905966  249    RG276   Small Pebbles      Sheas Creek
#
#      No_Inlet  No_Outlet  Pit_Depth_m
# 1           2          1          1.0
# ...

# %%
dataset2.iloc[:10,0]
# Out:
# 0    151.200169
# 1    151.221046
# 2    151.226207
# 3    151.226322
# 4    151.210474
# 5    151.210380
# 6    151.210390
# 7    151.210492
# 8    151.216062
# 9    151.213796
# Name: X, dtype: float64

# %%
dataset2[['X']]
# Out:
#               X
# 0    151.200169
# 1    151.221046
# 2    151.226207
# 3    151.226322
# 4    151.210474
# ..          ...
# 244  151.204822
# 245  151.204265
# 246  151.204233
# 247  151.204094
# 248  151.204135
#
# [249 rows x 1 columns]

# %%
modify_dataset = dataset2_0.tail(5)
modify_dataset
# Out:
#                 X          Y  FID asset_id       Material    Catchment  \
# RG270  151.204822 -33.906581  245    RG270  Small Pebbles  Sheas Creek
# RG272  151.204265 -33.905925  246    RG272  Small Pebbles  Sheas Creek
# RG273  151.204233 -33.905874  247    RG273  Small Pebbles  Sheas Creek
# RG275  151.204094 -33.905924  248    RG275  Small Pebbles  Sheas Creek
# RG276  151.204135 -33.905966  249    RG276  Small Pebbles  Sheas Creek
#
#        No_Inlet  No_Outlet  Pit_Depth_m
# RG270         1          1          1.0
# RG272         1          1          1.0
# RG273         1          1          1.0
# RG275         1          1          1.0
# RG276         1          1          1.0

# %%
modify_dataset.drop('asset_id', axis=1)
# Out:
#                 X          Y  FID       Material    Catchment  No_Inlet  \
# RG270  151.204822 -33.906581  245  Small Pebbles  Sheas Creek         1
# RG272  151.204265 -33.905925  246  Small Pebbles  Sheas Creek         1
# RG273  151.204233 -33.905874  247  Small Pebbles  Sheas Creek         1
# RG275  151.204094 -33.905924  248  Small Pebbles  Sheas Creek         1
# RG276  151.204135 -33.905966  249  Small Pebbles  Sheas Creek         1
#
#        No_Outlet  Pit_Depth_m
# RG270          1          1.0
# RG272          1          1.0
# RG273          1          1.0
# RG275          1          1.0
# RG276          1          1.0

# %%
modify_dataset.drop('RG270')
# Out:
#                 X          Y  FID asset_id       Material    Catchment  \
# RG272  151.204265 -33.905925  246    RG272  Small Pebbles  Sheas Creek
# RG273  151.204233 -33.905874  247    RG273  Small Pebbles  Sheas Creek
# RG275  151.204094 -33.905924  248    RG275  Small Pebbles  Sheas Creek
# RG276  151.204135 -33.905966  249    RG276  Small Pebbles  Sheas Creek
#
#        No_Inlet  No_Outlet  Pit_Depth_m
# RG272         1          1          1.0
# RG273         1          1          1.0
# RG275         1          1          1.0
# RG276         1          1          1.0

# %%
modify_dataset.drop('RG270')
# Out:
#                 X          Y  FID asset_id       Material    Catchment  \
# RG272  151.204265 -33.905925  246    RG272  Small Pebbles  Sheas Creek
# RG273  151.204233 -33.905874  247    RG273  Small Pebbles  Sheas Creek
# RG275  151.204094 -33.905924  248    RG275  Small Pebbles  Sheas Creek
# RG276  151.204135 -33.905966  249    RG276  Small Pebbles  Sheas Creek
#
#        No_Inlet  No_Outlet  Pit_Depth_m
# RG272         1          1          1.0
# RG273         1          1          1.0
# RG275         1          1          1.0
# RG276         1          1          1.0

# %%
modify_dataset.drop('RG270')
# Out:
#                 X          Y  FID asset_id       Material    Catchment  \
# RG272  151.204265 -33.905925  246    RG272  Small Pebbles  Sheas Creek
# RG273  151.204233 -33.905874  247    RG273  Small Pebbles  Sheas Creek
# RG275  151.204094 -33.905924  248    RG275  Small Pebbles  Sheas Creek
# RG276  151.204135 -33.905966  249    RG276  Small Pebbles  Sheas Creek
#
#        No_Inlet  No_Outlet  Pit_Depth_m
# RG272         1          1          1.0
# RG273         1          1          1.0
# RG275         1          1          1.0
# RG276         1          1          1.0

# %%
modify_dataset['Material'].loc['RG275']

# %%
x_mean = dataset2['X'].mean()
y_mean = dataset2['Y'].mean()

plt.figure(figsize=[16, 16], dpi=300)
plt.scatter(dataset2['X'], dataset2['Y'], color='#54778C')
plt.title('X coordinator distribution')
plt.xlabel('X Coordinator')
plt.ylabel('Y Coordinator')
plt.xticks(np.arange(151, 152, 0.5), labels='X coordinator')
plt.yticks(dataset2['Y'], labels='Y coordinator')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-99dd4a4a39e7> in <module>
#       7 plt.xlabel('X Coordinator')
#       8 plt.ylabel('Y Coordinator')
# ----> 9 plt.xticks(np.arange(151, 152, 0.5), labels='X coordinator')
#      10 plt.yticks(dataset2['Y'], labels='Y coordinator')
#      11 plt.legend()
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1657         labels = ax.get_xticklabels()
#    1658     else:
# -> 1659         labels = ax.set_xticklabels(labels, **kwargs)
#    1660     for l in labels:
#    1661         l.update(kwargs)
#
# c:\users\ashen\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ...
